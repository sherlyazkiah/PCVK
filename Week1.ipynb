# %% [markdown]
# <a href="https://colab.research.google.com/github/sherlyazkiah/PVCK/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
# Create a list to save the urls of several images
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://lh3.googleusercontent.com/pw/AP1GczNZtnk8Ra_Ak_I1x-wUGz6LMUGfd2CJvO_2MejYsXbY8hfOpAMZYDBciD23bWRVURvwqcCzI1C2otTYvnWxM1QphRMZ6Vy1Yg39hAzTfZD2eEBm_pwisT4VbsPB4-yInyP13yqOkQ-bKH6PCT7X8kl1=w736-h552-s-no-gm?authuser=0"]
# Read and display the image
# Loop through each image URL, multiple images can be saved to the list
for url in urls:
  image = io.imread(url)                          #read image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5) #resize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)  #convert color to RGB
  final_frame = cv.hconcat((image, image_2))      #concatenate image
  cv2_imshow(final_frame)                         #show image
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=736x276>

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ",tinggi," x ",lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  276  x  368
# <PIL.Image.Image image mode=RGB size=368x276>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Draw a horizontal line in the middle of the image
for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=736x276>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_vertical = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_diagonal = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Vertical line
for x in range (tinggi):
  image_vertical[x,int((lebar)/2)] = [255,255,255]

final_frame = cv.hconcat((image_2, image_vertical))
cv2_imshow(final_frame)

# First diagonal: top-left → bottom-right
for y in range (tinggi):
    x = int(y * lebar / tinggi)
    image_diagonal[y, x] = [255,255,255]

# Second diagonal: top-right → bottom-left
for y in range (tinggi):
    x = int(lebar - (y * lebar / tinggi) - 1)
    image_diagonal[y, x] = [255,255,255]

print('\n')
final_frame = cv.hconcat((image_2, image_diagonal))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=736x276>
# <PIL.Image.Image image mode=RGB size=736x276>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_horizontal2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

line_length = 100   # choose the length of the line
start_x = int((lebar - line_length) / 2) - 50
y_mid = int(tinggi / 2)

for x in range(start_x, start_x + line_length):
    image_horizontal2[y_mid, x] = [255,255,255]

final_frame = cv.hconcat((image_2, image_horizontal2))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=736x276>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_box = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Draw filled box at coordinates (100,100) to (180,180)
top_left = (100,100)
bottom_right = (180,180)

for y in range(top_left[1], bottom_right[1]):     # baris 100 - 179
    for x in range(top_left[0], bottom_right[0]): # kolom 100 - 179
        image_box[y, x] = [255,255,255]           # semua pixel jadi putih

final_frame = cv.hconcat((image_2, image_box))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=736x276>
